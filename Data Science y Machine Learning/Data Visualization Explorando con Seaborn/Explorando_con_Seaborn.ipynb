# %% [markdown]
# **Carpeta de visualizacion de datos a partir de la biblioteca Seaborn y pandas**
# https://seaborn.pydata.org/
# https://pandas.pydata.org/
# https://matplotlib.org/
# https://docs.scipy.org/doc/scipy/reference/stats.html

# %% [markdown]
# # Importando base de datos

# %%
import pandas as pd

# %%
datos = pd.read_csv('credit_card.csv')
datos
# Out:
#       LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE  \
# 0          6022              Yes       2.University  Married   24
# 1         36132              Yes       2.University   Single   26
# 2         27099              Yes       2.University   Single   34
# 3         15055              Yes       2.University  Married   37
# 4        150550               No  3.Graduate School   Single   29
# ...         ...              ...                ...      ...  ...
# 1495      54198              Yes  3.Graduate School   Single   27
# 1496      45165               No       2.University  Married   55
# 1497      78286               No  3.Graduate School   Single   34
# 1498       6022               No       2.University  Married   44
# 1499     183671               No  3.Graduate School   Single   31
#
#          BILL_AMT     PAY_AMT  DEFAULT
# 0        934.0122      0.0000        1
# 1        519.3975      0.0000        1
# 2       4223.5297    457.0698        0
# ...

# %%
datos.head(10)
# Out:
#    LIMIT_BAL CHECKING_ACCOUNT          EDUCATION MARRIAGE  AGE     BILL_AMT  \
# 0       6022              Yes       2.University  Married   24     934.0122
# 1      36132              Yes       2.University   Single   26     519.3975
# 2      27099              Yes       2.University   Single   34    4223.5297
# 3      15055              Yes       2.University  Married   37   14522.9563
# 4     150550               No  3.Graduate School   Single   29  124060.1253
# 5      30110              Yes       2.University   Single   23     114.4180
# 6      42154              Yes      1.High School  Married   28    4244.3056
# 7      60220              Yes      1.High School   Single   34    2946.8657
# 8      78286              Yes  3.Graduate School   Single   51    6524.8370
# 9     189693              Yes       2.University   Single   41    1957.1500
#
#       PAY_AMT  DEFAULT
# 0      0.0000        1
# 1      0.0000        1
# 2    457.0698        0
# 3    602.2000        0
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LIMIT_BAL         1500 non-null   int64
#  1   CHECKING_ACCOUNT  1500 non-null   object
#  2   EDUCATION         1500 non-null   object
#  3   MARRIAGE          1500 non-null   object
#  4   AGE               1500 non-null   int64
#  5   BILL_AMT          1500 non-null   float64
#  6   PAY_AMT           1500 non-null   float64
#  7   DEFAULT           1500 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 93.9+ KB

# %% [markdown]
# # Traduciendo las variables

# %%
datos.columns
# Out:
# Index(['LIMIT_BAL', 'CHECKING_ACCOUNT', 'EDUCATION', 'MARRIAGE', 'AGE',
#        'BILL_AMT', 'PAY_AMT', 'DEFAULT'],
#       dtype='object')

# %%
#Crear un diccionario para cambiar el nombre de las columnas
dic_colums = {'LIMIT_BAL':'Limite',
              'CHECKING_ACCOUNT':'CuentaCorriente',
              'EDUCATION': 'Educacion',
              'MARRIAGE':'EstadoCivil',
              'AGE':'Edad',
              'BILL_AMT': 'ValorFactura',
              'PAY_AMT':'ValorPago',
              'DEFAULT':'Mora'}

# %%
#Creo otro dataframe con los nombres de las columnas cambiadas
tarjetas = datos.rename(columns = dic_colums)
tarjetas
# Out:
#       Limite CuentaCorriente          Educacion EstadoCivil  Edad  \
# 0       6022             Yes       2.University     Married    24
# 1      36132             Yes       2.University      Single    26
# 2      27099             Yes       2.University      Single    34
# 3      15055             Yes       2.University     Married    37
# 4     150550              No  3.Graduate School      Single    29
# ...      ...             ...                ...         ...   ...
# 1495   54198             Yes  3.Graduate School      Single    27
# 1496   45165              No       2.University     Married    55
# 1497   78286              No  3.Graduate School      Single    34
# 1498    6022              No       2.University     Married    44
# 1499  183671              No  3.Graduate School      Single    31
#
#       ValorFactura   ValorPago  Mora
# 0         934.0122      0.0000     1
# 1         519.3975      0.0000     1
# 2        4223.5297    457.0698     0
# ...

# %%
tarjetas.head(10)
# Out:
#    Limite CuentaCorriente          Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022             Yes       2.University     Married    24      934.0122
# 1   36132             Yes       2.University      Single    26      519.3975
# 2   27099             Yes       2.University      Single    34     4223.5297
# 3   15055             Yes       2.University     Married    37    14522.9563
# 4  150550              No  3.Graduate School      Single    29   124060.1253
# 5   30110             Yes       2.University      Single    23      114.4180
# 6   42154             Yes      1.High School     Married    28     4244.3056
# 7   60220             Yes      1.High School      Single    34     2946.8657
# 8   78286             Yes  3.Graduate School      Single    51     6524.8370
# 9  189693             Yes       2.University      Single    41     1957.1500
#
#     ValorPago  Mora
# 0      0.0000     1
# 1      0.0000     1
# 2    457.0698     0
# 3    602.2000     0
# ...

# %%
#Ahora le cambio el contenido a las columnas(las traduzco), utilizo unique para ver los valores unicos
tarjetas.CuentaCorriente.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
#Hago el mismo proceso
dic_cuenta= {
    'Yes':'Si',
    'No':'No'
}

# %%
#.Map() te permite transformar un iterable completo usando otra función, osea cambiar todo el array
tarjetas.CuentaCorriente.map(dic_cuenta)
# Out:
# 0       Si
# 1       Si
# 2       Si
# 3       Si
# 4       No
#         ..
# 1495    Si
# 1496    No
# 1497    No
# 1498    No
# 1499    No
# Name: CuentaCorriente, Length: 1500, dtype: object

# %%
#Ahora lo cambio
tarjetas.CuentaCorriente = tarjetas.CuentaCorriente.map(dic_cuenta)

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente          Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si       2.University     Married    24      934.0122
# 1   36132              Si       2.University      Single    26      519.3975
# 2   27099              Si       2.University      Single    34     4223.5297
# 3   15055              Si       2.University     Married    37    14522.9563
# 4  150550              No  3.Graduate School      Single    29   124060.1253
#
#     ValorPago  Mora
# 0      0.0000     1
# 1      0.0000     1
# 2    457.0698     0
# 3    602.2000     0
# 4  16560.5000     0

# %%
#Ahora lo hacemos para la Educacion
tarjetas.Educacion.unique()
# Out:
# array(['2.University', '3.Graduate School', '1.High School'], dtype=object)

# %%
dic_Educacion = {
    '2.University':'2.Universidad',
    '3.Graduate School':'3.GraduadoCole',
    '1.High School':'1.Colegio'
}

# %%
tarjetas.Educacion = tarjetas.Educacion.map(dic_Educacion)

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad     Married    24      934.0122
# 1   36132              Si   2.Universidad      Single    26      519.3975
# 2   27099              Si   2.Universidad      Single    34     4223.5297
# 3   15055              Si   2.Universidad     Married    37    14522.9563
# 4  150550              No  3.GraduadoCole      Single    29   124060.1253
#
#     ValorPago  Mora
# 0      0.0000     1
# 1      0.0000     1
# 2    457.0698     0
# 3    602.2000     0
# 4  16560.5000     0

# %%
tarjetas.EstadoCivil.unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
dic_EstadoCivil = {
    'Married':'Casado',
    'Single':'Soltero'
}

# %%
tarjetas.EstadoCivil = tarjetas.EstadoCivil.map(dic_EstadoCivil)

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora
# 0      0.0000     1
# 1      0.0000     1
# 2    457.0698     0
# 3    602.2000     0
# 4  16560.5000     0

# %% [markdown]
# # **Importando Seaborn**

# %%
import seaborn as sns

# %%
#Para saber la version que esta instalada de seaborn
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.12.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: matplotlib, numpy, pandas
# Required-by: missingno

# %%
tarjetas.shape
# Out:
# (1500, 8)

# %%
tarjetas.head(10)
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
# 5   30110              Si   2.Universidad     Soltero    23      114.4180
# 6   42154              Si       1.Colegio      Casado    28     4244.3056
# 7   60220              Si       1.Colegio     Soltero    34     2946.8657
# 8   78286              Si  3.GraduadoCole     Soltero    51     6524.8370
# 9  189693              Si   2.Universidad     Soltero    41     1957.1500
#
#     ValorPago  Mora
# 0      0.0000     1
# 1      0.0000     1
# 2    457.0698     0
# 3    602.2000     0
# 4  16560.5000     0
# 5    114.4180     0
# ...

# %% [markdown]
# # **Analisis 1: Primeros pasos**

# %%
#Hacemos nuestro primer grafico
sns.distplot(tarjetas['Limite'])
# Out:
# <ipython-input-106-1f753d59beb9>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tarjetas['Limite'])
# <Axes: xlabel='Limite', ylabel='Density'>

# %%
#Como el grafico tiene una funcion vieja y la van a quitar, pongo lo siguiente
sns.displot(tarjetas['Limite']);

# %%
#Tambien lo podemos poner de la siguiente manera, el ';' al final saca la info molesta
sns.displot(tarjetas, x='Limite');

# %%
#Si queremos que intervengan valores entre si
sns.displot(tarjetas, x='Limite', hue = 'Educacion');

# %% [markdown]
# # **Analisis 2: Creando variable numérica**

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora
# 0      0.0000     1
# 1      0.0000     1
# 2    457.0698     0
# 3    602.2000     0
# 4  16560.5000     0

# %%
#Creamos una columna que diga cuato uso de su limite de pago (porcentaje de uso)
#iu:indice de uso se lo llama en los bancos
tarjetas['iu'] = tarjetas['ValorFactura']/tarjetas['Limite']

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu
# 0      0.0000     1  0.155100
# 1      0.0000     1  0.014375
# 2    457.0698     0  0.155856
# 3    602.2000     0  0.964660
# 4  16560.5000     0  0.824046

# %%
#El analisis de cuanto usan las personas respecto al limite que tiene la tarjeta
sns.displot(data=tarjetas, x='iu');

# %% [markdown]
# Hay gente que usa poco del limite que tiene disponible

# %% [markdown]
# # **Estilos y colores**

# %%
#Le monemos una grilla de fondo para darle mas contexto al analisis
#el sns.set_style('white') es el original
sns.set_style('whitegrid')

# %%
sns.displot(tarjetas, x='Limite', hue = 'Educacion');

# %%
sns.set_style('darkgrid')

# %%
sns.displot(tarjetas, x='Limite', hue = 'Educacion');

# %%
#podemos poner palette y buscar en https://matplotlib.org/ el color que queramos
sns.displot(tarjetas, x='Limite', hue = 'Educacion', palette = 'inferno');

# %%
#para que los colores queden invertidos hay que colocar _r
sns.displot(tarjetas, x='Limite', hue = 'Educacion', palette = 'inferno_r');

# %% [markdown]
# # **Analisis de variables categóricas**

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu
# 0      0.0000     1  0.155100
# 1      0.0000     1  0.014375
# 2    457.0698     0  0.155856
# 3    602.2000     0  0.964660
# 4  16560.5000     0  0.824046

# %%
#Analizar si hay mas gente sin cuenta corriente o si hay mas gente con cuenta corriente
sns.countplot(x='CuentaCorriente', data = tarjetas);

# %%
#Ver si las personas mque deben estan o no en la gente que tiene cuenta corriente
sns.countplot(x='CuentaCorriente', data = tarjetas, hue = 'Mora');

# %% [markdown]
# En terminos relativos estan ubicados en las personas ue no tienen cuenta corriente

# %%
#Pongo otro estilo
sns.countplot(x='CuentaCorriente', data = tarjetas, hue = 'Mora',palette = 'coolwarm');

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu
# 0      0.0000     1  0.155100
# 1      0.0000     1  0.014375
# 2    457.0698     0  0.155856
# 3    602.2000     0  0.964660
# 4  16560.5000     0  0.824046

# %%
sns.catplot(x = 'EstadoCivil', y = 'Limite', data = tarjetas);

# %%
sns.catplot(x = 'EstadoCivil', y = 'Limite', data = tarjetas, hue = 'Mora');

# %%
#separarlos
sns.catplot(x = 'EstadoCivil', y = 'Limite', data = tarjetas, hue = 'Mora', dodge = True);

# %% [markdown]
# Pregunta: Sera que la edad tiene que ver con lo que gastan las personas

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu
# 0      0.0000     1  0.155100
# 1      0.0000     1  0.014375
# 2    457.0698     0  0.155856
# 3    602.2000     0  0.964660
# 4  16560.5000     0  0.824046

# %%
sns.swarmplot(x ='Educacion', y = 'iu', data = tarjetas)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Educacion', ylabel='iu'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 15.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 27.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Boxplot y Violinplot

# %%
sns.boxplot(x ='Educacion', y = 'iu', data = tarjetas );

# %%
sns.boxplot(x ='Educacion', y = 'iu', data = tarjetas, hue='Mora');

# %%
sns.boxplot(x ='Educacion', y = 'iu', data = tarjetas, hue='Mora',palette='bone');

# %%
sns.violinplot(x ='Educacion', y = 'iu', data = tarjetas);

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu
# 0      0.0000     1  0.155100
# 1      0.0000     1  0.014375
# 2    457.0698     0  0.155856
# 3    602.2000     0  0.964660
# 4  16560.5000     0  0.824046

# %%
tarjetas.Edad.unique()
# Out:
# array([24, 26, 34, 37, 29, 23, 28, 51, 41, 30, 49, 39, 40, 47, 27, 33, 32,
#        54, 58, 22, 31, 25, 42, 45, 57, 56, 44, 35, 53, 43, 38, 63, 36, 52,
#        46, 50, 48, 75, 55, 73, 59, 21, 60, 67, 61, 62, 70, 72])

# %%
#Para diferenciar en rangos etareos hacemos un conjunto y recortamos los sectores dandoles nombre
bins = [20,30,40,50,100]
nombres = ['20-30','30-40','40-50', '50+']

tarjetas['rango_edad'] = pd.cut(tarjetas['Edad'], bins, labels = nombres)

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu rango_edad
# 0      0.0000     1  0.155100      20-30
# 1      0.0000     1  0.014375      20-30
# 2    457.0698     0  0.155856      30-40
# 3    602.2000     0  0.964660      30-40
# 4  16560.5000     0  0.824046      20-30

# %%
sns.boxplot(x = 'rango_edad', y = 'Limite', data = tarjetas);

# %% [markdown]
# # **Analisis de variables numéricas**

# %% [markdown]
# Grafico de distribución

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu rango_edad
# 0      0.0000     1  0.155100      20-30
# 1      0.0000     1  0.014375      20-30
# 2    457.0698     0  0.155856      30-40
# 3    602.2000     0  0.964660      30-40
# 4  16560.5000     0  0.824046      20-30

# %%
#Pasar de este que esta mezclado con 3 graficos diferentes al siguiente
sns.displot(data=tarjetas, x = 'Limite', hue = 'Educacion');

# %%
#En vez de usar el hue, uso el col
sns.displot(data=tarjetas, x = 'Limite', col = 'Educacion');

# %%
#La densidad de cada uno
sns.displot(data=tarjetas, x = 'Limite', col = 'Educacion', kind = 'kde');

# %%
#Analisis a partir del indice de densidad y la Mora de cada uno
sns.displot(data=tarjetas, x = 'Limite', col = 'Educacion', kind = 'kde',hue = 'Mora');

# %%
##Analisis a partir del indice de densidad y el rango etareo de cada uno
sns.displot(data=tarjetas, x = 'Limite', col = 'Educacion', kind = 'kde',hue = 'rango_edad');

# %% [markdown]
# Grafico de dispersión

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu rango_edad
# 0      0.0000     1  0.155100      20-30
# 1      0.0000     1  0.014375      20-30
# 2    457.0698     0  0.155856      30-40
# 3    602.2000     0  0.964660      30-40
# 4  16560.5000     0  0.824046      20-30

# %%
sns.scatterplot(x = 'iu', y = 'ValorFactura', data = tarjetas);

# %% [markdown]
# a medida que aumenta la factura, aumenta el indice de uso

# %%
sns.scatterplot(x = 'iu', y = 'ValorFactura', data = tarjetas, hue='CuentaCorriente');

# %%
sns.lmplot(x = 'iu', y = 'ValorFactura', data = tarjetas);

# %% [markdown]
# # **Test de hipótesis**

# %%
sns.lmplot(x = 'iu', y = 'ValorFactura', data = tarjetas);

# %%
#Los que deben la mora y los que no
sns.lmplot(x = 'iu', y = 'ValorFactura', data = tarjetas, col='Mora');

# %% [markdown]
# # **Test de hipótesis**

# %% [markdown]
# utilizo la libreria
#
# > https://docs.scipy.org/doc/scipy/reference/stats.html
#
# Creamos una hipótesis

# %%
#Utilizo la libreria scipy.stats
from scipy.stats import ranksums

# %% [markdown]
# H<sup>null<null>
#
#
# ---
# La distribucion de los grupos con mora y sin mora son la misma

# %% [markdown]
# H<sup>null<null>
#
#
# ---
# La distribucion de los grupos con mora y sin mora **NO** son la misma

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu rango_edad
# 0      0.0000     1  0.155100      20-30
# 1      0.0000     1  0.014375      20-30
# 2    457.0698     0  0.155856      30-40
# 3    602.2000     0  0.964660      30-40
# 4  16560.5000     0  0.824046      20-30

# %%
#Calcular cuantos son los que deben algo a partir de la mora
Deudor = tarjetas.query('Mora == 1').ValorFactura
Deudor
# Out:
# 0         934.0122
# 1         519.3975
# 38      10891.0881
# 45        330.6078
# 47       7316.7300
#            ...
# 1448     1619.0147
# 1472    17048.2820
# 1475     4402.0820
# 1478     1851.1628
# 1495      295.0780
# Name: ValorFactura, Length: 117, dtype: float64

# %%
NoDeudor = tarjetas.query('Mora == 0').ValorFactura
NoDeudor
# Out:
# 2         4223.5297
# 3        14522.9563
# 4       124060.1253
# 5          114.4180
# 6         4244.3056
#            ...
# 1494     32698.2556
# 1496     23637.8555
# 1497       962.9178
# 1498       864.7592
# 1499     97022.8508
# Name: ValorFactura, Length: 1383, dtype: float64

# %%
#Vemos la diferencia entre las 2
resultado = ranksums(Deudor, NoDeudor)
resultado
# Out:
# RanksumsResult(statistic=-2.562530598426702, pvalue=0.010391243081223555)

# %%
print(f'El p-value de nuestro test es {resultado.pvalue}')
# Out:
# El p-value de nuestro test es 0.010391243081223555

# %% [markdown]
# # **JointPlot**

# %%
tarjetas.head()
# Out:
#    Limite CuentaCorriente       Educacion EstadoCivil  Edad  ValorFactura  \
# 0    6022              Si   2.Universidad      Casado    24      934.0122
# 1   36132              Si   2.Universidad     Soltero    26      519.3975
# 2   27099              Si   2.Universidad     Soltero    34     4223.5297
# 3   15055              Si   2.Universidad      Casado    37    14522.9563
# 4  150550              No  3.GraduadoCole     Soltero    29   124060.1253
#
#     ValorPago  Mora        iu rango_edad
# 0      0.0000     1  0.155100      20-30
# 1      0.0000     1  0.014375      20-30
# 2    457.0698     0  0.155856      30-40
# 3    602.2000     0  0.964660      30-40
# 4  16560.5000     0  0.824046      20-30

# %%
sns.jointplot(x = 'Edad', y = 'Limite', data = tarjetas);

# %%
sns.jointplot(x='Edad', y='iu', data=tarjetas, kind='scatter');

# %%
sns.jointplot(x = 'Edad', y = 'Limite', data = tarjetas, kind = 'kde');

# %%
sns.jointplot(x = 'Edad', y = 'Limite', data = tarjetas, kind = 'hex');

# %%
sns.jointplot(x = 'Edad', y = 'Limite', data = tarjetas, kind = 'kde', hue='Mora');

# %% [markdown]
# # **Pairplot**

# %% [markdown]
# analisis rapido y de todo

# %%
tarjetas.describe()
# Out:
#               Limite         Edad   ValorFactura     ValorPago         Mora  \
# count    1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean    51221.943333    35.212667   15459.869900   1984.869266     0.078000
# std     39424.407462     9.274955   20722.582831   5296.771686     0.268261
# min      3011.000000    21.000000      27.701200      0.000000     0.000000
# 25%     18066.000000    28.000000    2035.586550    407.011925     0.000000
# 50%     42154.000000    33.500000    7701.385250    759.374200     0.000000
# 75%     72264.000000    41.000000   20671.568850   1705.279850     0.000000
# max    210770.000000    75.000000  141792.506500  97022.850800     1.000000
#
#                 iu
# count  1500.000000
# mean      0.388237
# std       0.341923
# min       0.000188
# 25%       0.049209
# 50%       0.308976
# 75%       0.704090
# max       0.998010

# %%
sns.pairplot(data = tarjetas);

# %%
sns.pairplot(data = tarjetas, hue = 'Educacion', palette = 'cividis');
