# %% [markdown]
# <a href="https://colab.research.google.com/github/Alfonio/Proyectos-de-Python/blob/main/Importando_la_base_de_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Trabajando con datos**

# %% [markdown]
# Importe del archivo y analisis
# Para info de teclas control + m + h

# %% [markdown]
# # **Leer archivo .json**

# %%
import pandas as pd

# %%
#como importar un archivo .json
json = open('Datos/alquiler.json')

# %%
#Para leer el archivo
print(json.read())
# Out:
# [{"Tipo":"Habitación","Distrito":"San Borja","Cuartos":1,"Vacantes":0,"Suites":0,"Area":40,"Valor":1700.0,"Mantenimiento":500.0,"Impuesto":60.0},
# {"Tipo":"Casa","Distrito":"Lurigancho","Cuartos":2,"Vacantes":0,"Suites":1,"Area":100,"Valor":7000.0,"Mantenimiento":null,"Impuesto":null},
# {"Tipo":"Local comercial","Distrito":"Ate","Cuartos":0,"Vacantes":4,"Suites":0,"Area":150,"Valor":5200.0,"Mantenimiento":4020.0,"Impuesto":1111.0},
# {"Tipo":"Departamento","Distrito":"Pachacámac","Cuartos":1,"Vacantes":0,"Suites":0,"Area":15,"Valor":800.0,"Mantenimiento":390.0,"Impuesto":20.0},
# {"Tipo":"Departamento","Distrito":"Ate","Cuartos":1,"Vacantes":0,"Suites":0,"Area":48,"Valor":800.0,"Mantenimiento":230.0,"Impuesto":null},
# {"Tipo":"Departamento","Distrito":"Barranco","Cuartos":3,"Vacantes":1,"Suites":0,"Area":70,"Valor":1200.0,"Mantenimiento":null,"Impuesto":null},
# ...

# %%
#Almacenar un json en una biblioteca pandas
df_json = pd.read_json('Datos/alquiler.json')

# %%
df_json
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %% [markdown]
# # **Leer archivo .txt**

# %%
#Leer archivo txt
txt = open('Datos/alquiler.txt')

# %%
print(txt.read())
# Out:
# Tipo	Distrito	Cuartos	Vacantes	Suites	Area	Valor	Mantenimiento	Impuesto
# Habitación	San Borja	1	0	0	40	1700	500	60
# Casa	Lurigancho	2	0	1	100	7000
# Local comercial	Ate	0	4	0	150	5200	4020	1111
# Departamento	Pachacámac	1	0	0	15	800	390	20
# Departamento	Ate	1	0	0	48	800	230
# Departamento	Barranco	3	1	0	70	1200
# Departamento	Comas	2	0	0	50	1300	301	17
# Casa en condominio	Ate	5	4	5	750	22000
# Casa en condominio	El Agustino	2	2	0	65	1000
# Local comercial	Pachacámac	0	3	0	695	35000	19193	3030

# %%
df_txt = pd.read_table('Datos/alquiler.txt')

# %%
df_txt
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %% [markdown]
# # **Leer archivo .xlsx**

# %%
df_excel = pd.read_excel('Datos/alquiler.xlsx')

# %%
df_excel
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700
# 1                Casa   Lurigancho        2         0       1   100   7000
# 2     Local comercial          Ate        0         4       0   150   5200
# 3        Departamento   Pachacámac        1         0       0    15    800
# 4        Departamento          Ate        1         0       0    48    800
# 5        Departamento     Barranco        3         1       0    70   1200
# 6        Departamento        Comas        2         0       0    50   1300
# 7  Casa en condominio          Ate        5         4       5   750  22000
# 8  Casa en condominio  El Agustino        2         2       0    65   1000
# 9     Local comercial   Pachacámac        0         3       0   695  35000
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2         4020.0    1111.0
# 3          390.0      20.0
# ...

# %% [markdown]
# # **Leer archivo .html o pagina web**

# %%
#Este metodo es solo para pagina web que no cambia el contenido y es siempre el mismo
df_html1 =  pd.read_html('Datos/datos_html_1.html')

# %%
# lo pasa con [], como un array, poner [0] para solucionarlo
df_html1[0]
# Out:
#      Año                           Campeón                        Subcampeón  \
# 0   2018                           Francia                           Croacia
# 1   2014                          Alemania                         Argentina
# 2   2010                            España                           Holanda
# 3   2006                            Italia                           Francia
# 4   2002                            Brasil                          Alemania
# ..   ...                               ...                               ...
# 18  1946  No celebrado (II Guerra Mundial)  No celebrado (II Guerra Mundial)
# 19  1942  No celebrado (II Guerra Mundial)  No celebrado (II Guerra Mundial)
# 20  1938                            Italia                           Hungría
# 21  1934                            Italia                    Checoslovaquia
# 22  1930                           Uruguay                         Argentina
#
#                                 Sede
# ...

# %%
#Esta es para una pagina ejemplo que cambia el contenido a menudo, se coloca el link https o link de la pagina web
df_html =  pd.read_html('https://pokemon.fandom.com/es/wiki/Lista_de_Pok%C3%A9mon_con_sus_estad%C3%ADsticas_base')
df_html[0]
# Out:
#        #                       Pokémon   PS  Ataque  Defensa  ...  \
# 0      1                     Bulbasaur   45      49       49  ...
# 1      2                       Ivysaur   60      62       63  ...
# 2      3                      Venusaur   80      82       83  ...
# 3      3                 Mega-Venusaur   80     100      123  ...
# 4      4                    Charmander   39      52       43  ...
# ..   ...                           ...  ...     ...      ...  ...
# 992  888       Zacian (Espada Suprema)   92     170      115  ...
# 993  889  Zamazenta (Guerrero Avezado)   92     130      115  ...
# 994  889    Zamazenta (Escudo Supremo)   92     130      115  ...
# 995  890                     Eternatus  140      85       95  ...
# 996  890         Eternatus (Eternamax)  255     115      250  ...
#
#      Defensa esp.  Velocidad  Promedio     σ  Suma
# 0              65         45      5300   864   318
# 1              80         60      6750   890   405
# ...

# %%
#Con cuantas tablas se carga, dependiendo que tabla quiera tengo que indicarlo
len(df_html[0])
# Out:
# 997

# %%
df_html[1]
# Out:
#                       Clasificaciones de los Pokémon  \
#                                          Por Pokédex
# 0  Pokédex Nacional Kanto (1ª gen.) Johto (2ª gen...
#
#                                                       \
#                                        Por atributos
# 0  Por tipos Por grupos huevo Por especie Por alt...
#
#                                                       \
#                                     Por estadísticas
# 0  Por estadísticas base Por ratio de captura Por...
#
#
#                                           Miscelánea
# 0  Alfabéticamente Numéricamente Por generación P...

# %%
#si tuviera 2 tablas pongo  df_html[2] df_html[3]... etc

# %% [markdown]
# En esta aula, aprendimos:
#
# Cómo importar la biblioteca (import pandas as pd)
# Cómo leer diferentes fuentes de datos:
# Una base CSV (pd.read_csv(...))
# Una base JSON (pd.read_json(...))
# Una base TXT (pd.read_table(...))
# Un archivo EXCEL (pd.read_excel(...))
# Una página HTML (pd.read_html(...))
# Varios métodos y atributos útiles de dataframes, como:
# info()
# head()
# dtypes
# columns
# shape
# Y sobre Colab, vimos cómo:
#
# Crear diferentes tipos de células dentro del notebook
# Acceder a la documentación
# Cómo re-ejecutar todas las células
